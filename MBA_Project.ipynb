# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

import warnings
warnings.filterwarnings("ignore")

# %%
# read dataset
# https://archive.ics.uci.edu/dataset/352/online+retail
df=pd.read_excel("Online Retail.xlsx")

# %%
#check dimensions of data
df.shape
# Out:
# (541909, 8)

# %%
df.sample(10)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 145182    548870     21623         VINTAGE UNION JACK MEMOBOARD         1
# 250768    559048     21975       PACK OF 60 DINOSAUR CAKE CASES       720
# 528607    580729     23395       BELLE JARDINIERE CUSHION COVER         2
# 284042    561820     23201                   JUMBO BAG ALPHABET         2
# 174832    551855     21912             VINTAGE SNAKES & LADDERS         3
# 331472    566017     22386              JUMBO BAG PINK POLKADOT        10
# 81054     543107     23230                 WRAP ALPHABET DESIGN        25
# 281301    561515    84031B  CHARLIE LOLA BLUE HOT WATER BOTTLE          1
# 185755    552825     22355            CHARLOTTE BAG SUKI DESIGN        10
# 535540    581217     22090              PAPER BUNTING RETROSPOT         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 145182 2011-04-04 14:41:00       9.95     14606.0  United Kingdom
# 250768 2011-07-05 15:48:00       0.40     13027.0  United Kingdom
# 528607 2011-12-05 17:24:00      10.79         NaN  United Kingdom
# 284042 2011-07-29 16:00:00       4.13         NaN  United Kingdom
# 174832 2011-05-04 15:08:00       3.75     12836.0  United Kingdom
# 331472 2011-09-08 12:27:00       2.08     13330.0  United Kingdom
# 81054  2011-02-03 12:27:00       0.42     13800.0  United Kingdom
# 281301 2011-07-27 15:16:00       4.13         NaN  United Kingdom
# 185755 2011-05-11 13:18:00       0.85     15296.0  United Kingdom
# 535540 2011-12-08 09:20:00       5.79         NaN  United Kingdom

# %%
df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# Droping description with null
df.dropna(axis=0,subset=["Description"],inplace=True)

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description         0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     133626
# Country             0
# dtype: int64

# %%
# remove extra white spaces in description
df['Description'] = df['Description'].str.replace(r'\s+', ' ', regex=True)
df['Description'] = df['Description'].str.strip()

# %%
# checking for cancelld orders
df['InvoiceNo'].str.contains('C').sum()
# Out:
# 9288

# %%
# Remove cancelled orders
df = df[~df['InvoiceNo'].str.contains('C', na=False)]

# %%
df['InvoiceNo'].str.contains('C').sum()
# Out:
# 0

# %%
#convert Invoice no to string
df['InvoiceNo'] = df['InvoiceNo'].astype(str)

# %%
print("total number of countries",df["Country"].nunique())
df["Country"].value_counts(normalize=True)
# Out:
# total number of countries 38
# United Kingdom          0.915283
# Germany                 0.017023
# France                  0.015829
# EIRE                    0.014862
# Spain                   0.004678
# Netherlands             0.004449
# Belgium                 0.003824
# Switzerland             0.003703
# Portugal                0.002826
# Australia               0.002231
# Norway                  0.002018
# Italy                   0.001427
# Channel Islands         0.001408
# Finland                 0.001290
# Cyprus                  0.001156
# Sweden                  0.000849
# Unspecified             0.000840
# Austria                 0.000749
# Denmark                 0.000715
# Poland                  0.000621
# Japan                   0.000604
# Israel                  0.000555
# Hong Kong               0.000535
# Singapore               0.000418
# Iceland                 0.000343
# USA                     0.000337
# Canada                  0.000284
# Greece                  0.000273
# Malta                   0.000211
# United Arab Emirates    0.000128
# European Community      0.000113
# RSA                     0.000109
# Lebanon                 0.000085
# Lithuania               0.000066
# Brazil                  0.000060
# Czech Republic          0.000047
# Bahrain                 0.000034
# Saudi Arabia            0.000017
# Name: Country, dtype: float64

# %%
# Lets focus on United Kingdom
grouped_df=(df[df["Country"]=="Germany"]
           .groupby(["InvoiceNo","Description"])
           .size() # counts
           .unstack() 
           .fillna(0)
           .reset_index()
           .set_index("InvoiceNo"))

# %%
grouped_df.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536527                          0.0                         0.0
# 536840                          0.0                         0.0
# 536861                          0.0                         0.0
# 536967                          0.0                         0.0
# 536983                          0.0                         0.0
#
# Description  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 536527                                    0.0
# 536840                                    0.0
# 536861                                    0.0
# 536967                                    0.0
# 536983                                    0.0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536527                                   0.0                            0.0
# 536840                                   0.0                            0.0
# 536861                                   0.0                            0.0
# 536967                                   0.0                            0.0
# 536983                                   0.0                            0.0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS SMALL TUBE SKULL  \
# InvoiceNo
# 536527                                       0.0                          0.0
# 536840                                       0.0                          0.0
# 536861                                       0.0                          0.0
# 536967                                       0.0                          0.0
# 536983                                       0.0                          0.0
#
# Description  12 PENCILS TALL TUBE POSY  12 PENCILS TALL TUBE RED RETROSPOT  \
# InvoiceNo
# 536527                             0.0                                 0.0
# 536840                             0.0                                 0.0
# 536861                             0.0                                 0.0
# 536967                             0.0                                 0.0
# 536983                             0.0                                 0.0
#
# Description  12 PENCILS TALL TUBE SKULLS  ...  YULETIDE IMAGES GIFT WRAP SET  \
# InvoiceNo                                 ...
# 536527                               0.0  ...                            0.0
# 536840                               0.0  ...                            0.0
# 536861                               0.0  ...                            0.0
# 536967                               0.0  ...                            0.0
# 536983                               0.0  ...                            0.0
#
# Description  ZINC BOX SIGN HOME  ZINC FOLKART SLEIGH BELLS  \
# InvoiceNo
# 536527                      0.0                        0.0
# 536840                      0.0                        0.0
# 536861                      0.0                        0.0
# 536967                      0.0                        0.0
# 536983                      0.0                        0.0
#
# Description  ZINC HEART LATTICE T-LIGHT HOLDER  ZINC HEART T-LIGHT HOLDER  \
# InvoiceNo
# 536527                                     0.0                        0.0
# 536840                                     0.0                        0.0
# 536861                                     0.0                        0.0
# 536967                                     0.0                        0.0
# 536983                                     0.0                        0.0
#
# Description  ZINC METAL HEART DECORATION  ZINC STAR T-LIGHT HOLDER  \
# InvoiceNo
# 536527                               0.0                       0.0
# 536840                               0.0                       0.0
# 536861                               0.0                       0.0
# 536967                               0.0                       0.0
# 536983                               0.0                       0.0
#
# Description  ZINC T-LIGHT HOLDER STAR LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# InvoiceNo
# 536527                                  0.0                              0.0
# 536840                                  0.0                              0.0
# 536861                                  0.0                              0.0
# 536967                                  0.0                              0.0
# 536983                                  0.0                              0.0
#
# Description  ZINC WILLIE WINKIE CANDLE STICK
# InvoiceNo
# 536527                                   0.0
# 536840                                   0.0
# 536861                                   0.0
# 536967                                   0.0
# 536983                                   0.0
#
# [5 rows x 1693 columns]

# %%
# all positive values are converted to 1 and anything less than 0 to 0
def custom_encoding(x):
    if x<=0:
        return 0
    if x>=1:
        return 1
grouped_df=grouped_df.applymap(custom_encoding)
grouped_df.drop("POSTAGE",inplace=True,axis=1)

# %%
grouped_df.sample(10)
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 552878                            1                           0
# 541093                            0                           0
# 552008                            0                           0
# 543121                            0                           0
# 545988                            0                           0
# 555162                            1                           0
# 550354                            0                           0
# 539446                            0                           0
# 575750                            0                           0
# 572061                            0                           0
#
# Description  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 552878                                      0
# 541093                                      0
# 552008                                      0
# 543121                                      0
# 545988                                      0
# 555162                                      0
# 550354                                      0
# 539446                                      0
# 575750                                      0
# 572061                                      0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 552878                                     0                              0
# 541093                                     0                              0
# 552008                                     0                              0
# 543121                                     0                              0
# 545988                                     0                              0
# 555162                                     0                              0
# 550354                                     0                              0
# 539446                                     0                              0
# 575750                                     0                              0
# 572061                                     0                              0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS SMALL TUBE SKULL  \
# InvoiceNo
# 552878                                         0                            0
# 541093                                         0                            0
# 552008                                         0                            0
# 543121                                         0                            0
# 545988                                         0                            0
# 555162                                         0                            0
# 550354                                         0                            0
# 539446                                         0                            0
# 575750                                         0                            0
# 572061                                         0                            0
#
# Description  12 PENCILS TALL TUBE POSY  12 PENCILS TALL TUBE RED RETROSPOT  \
# InvoiceNo
# 552878                               0                                   0
# 541093                               0                                   0
# 552008                               0                                   0
# 543121                               0                                   0
# 545988                               0                                   0
# 555162                               0                                   0
# 550354                               0                                   0
# 539446                               0                                   0
# 575750                               0                                   0
# 572061                               0                                   0
#
# Description  12 PENCILS TALL TUBE SKULLS  ...  YULETIDE IMAGES GIFT WRAP SET  \
# InvoiceNo                                 ...
# 552878                                 0  ...                              0
# 541093                                 0  ...                              0
# 552008                                 0  ...                              0
# 543121                                 0  ...                              0
# 545988                                 0  ...                              0
# 555162                                 0  ...                              0
# 550354                                 0  ...                              0
# 539446                                 0  ...                              0
# 575750                                 0  ...                              0
# 572061                                 0  ...                              0
#
# Description  ZINC BOX SIGN HOME  ZINC FOLKART SLEIGH BELLS  \
# InvoiceNo
# 552878                        0                          0
# 541093                        0                          0
# 552008                        0                          0
# 543121                        0                          0
# 545988                        0                          0
# 555162                        0                          0
# 550354                        0                          0
# 539446                        0                          0
# 575750                        0                          0
# 572061                        0                          0
#
# Description  ZINC HEART LATTICE T-LIGHT HOLDER  ZINC HEART T-LIGHT HOLDER  \
# InvoiceNo
# 552878                                       0                          0
# 541093                                       0                          0
# 552008                                       0                          0
# 543121                                       0                          0
# 545988                                       0                          0
# 555162                                       0                          0
# 550354                                       0                          0
# 539446                                       0                          0
# 575750                                       0                          0
# 572061                                       0                          0
#
# Description  ZINC METAL HEART DECORATION  ZINC STAR T-LIGHT HOLDER  \
# InvoiceNo
# 552878                                 0                         0
# 541093                                 0                         0
# 552008                                 0                         0
# 543121                                 0                         0
# 545988                                 0                         0
# 555162                                 0                         0
# 550354                                 0                         0
# 539446                                 0                         0
# 575750                                 0                         0
# 572061                                 0                         0
#
# Description  ZINC T-LIGHT HOLDER STAR LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# InvoiceNo
# 552878                                    0                                0
# 541093                                    0                                0
# 552008                                    0                                0
# 543121                                    0                                0
# 545988                                    0                                0
# 555162                                    0                                0
# 550354                                    0                                0
# 539446                                    0                                0
# 575750                                    0                                0
# 572061                                    0                                0
#
# Description  ZINC WILLIE WINKIE CANDLE STICK
# InvoiceNo
# 552878                                     0
# 541093                                     0
# 552008                                     0
# 543121                                     0
# 545988                                     0
# 555162                                     0
# 550354                                     0
# 539446                                     0
# 575750                                     0
# 572061                                     0
#
# [10 rows x 1692 columns]

# %%
frequent_itemset=apriori(grouped_df,min_support=0.05,use_colnames=True)

# %%
rules=association_rules(frequent_itemset,metric="confidence",min_threshold=0.3)

# %%
 rules.sort_values(by="lift",ascending=False)
# Out:
#                              antecedents  \
# 9               (WOODLAND CHARLOTTE BAG)
# 10         (RED RETROSPOT CHARLOTTE BAG)
# 0     (PLASTERS IN TIN WOODLAND ANIMALS)
# 1        (PLASTERS IN TIN CIRCUS PARADE)
# 5     (PLASTERS IN TIN WOODLAND ANIMALS)
# 6             (PLASTERS IN TIN SPACEBOY)
# 11   (ROUND SNACK BOXES SET OF 4 FRUITS)
# 12  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 13                  (SPACEBOY LUNCH BOX)
# 2    (ROUND SNACK BOXES SET OF 4 FRUITS)
# 3        (PLASTERS IN TIN CIRCUS PARADE)
# 8   (ROUND SNACK BOXES SET OF4 WOODLAND)
# 7     (PLASTERS IN TIN WOODLAND ANIMALS)
# 14              (WOODLAND CHARLOTTE BAG)
# 4        (PLASTERS IN TIN CIRCUS PARADE)
#
#                              consequents  antecedent support  \
# 9          (RED RETROSPOT CHARLOTTE BAG)            0.126915
# 10              (WOODLAND CHARLOTTE BAG)            0.070022
# 0        (PLASTERS IN TIN CIRCUS PARADE)            0.137856
# 1     (PLASTERS IN TIN WOODLAND ANIMALS)            0.115974
# 5             (PLASTERS IN TIN SPACEBOY)            0.137856
# 6     (PLASTERS IN TIN WOODLAND ANIMALS)            0.107221
# 11  (ROUND SNACK BOXES SET OF4 WOODLAND)            0.157549
# 12   (ROUND SNACK BOXES SET OF 4 FRUITS)            0.245077
# 13  (ROUND SNACK BOXES SET OF4 WOODLAND)            0.102845
# 2        (PLASTERS IN TIN CIRCUS PARADE)            0.157549
# 3    (ROUND SNACK BOXES SET OF 4 FRUITS)            0.115974
# 8     (PLASTERS IN TIN WOODLAND ANIMALS)            0.245077
# 7   (ROUND SNACK BOXES SET OF4 WOODLAND)            0.137856
# 14  (ROUND SNACK BOXES SET OF4 WOODLAND)            0.126915
# 4   (ROUND SNACK BOXES SET OF4 WOODLAND)            0.115974
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 9             0.070022  0.059081    0.465517  6.648168  0.050194    1.739959
# 10            0.126915  0.059081    0.843750  6.648168  0.050194    5.587746
# 0             0.115974  0.067834    0.492063  4.242887  0.051846    1.740427
# 1             0.137856  0.067834    0.584906  4.242887  0.051846    2.076984
# 5             0.107221  0.061269    0.444444  4.145125  0.046488    1.607002
# 6             0.137856  0.061269    0.571429  4.145125  0.046488    2.011670
# 11            0.245077  0.131291    0.833333  3.400298  0.092679    4.529540
# 12            0.157549  0.131291    0.535714  3.400298  0.092679    1.814509
# 13            0.245077  0.070022    0.680851  2.778116  0.044817    2.365427
# 2             0.115974  0.050328    0.319444  2.754455  0.032057    1.298977
# 3             0.157549  0.050328    0.433962  2.754455  0.032057    1.488330
# 8             0.137856  0.074398    0.303571  2.202098  0.040613    1.237951
# 7             0.245077  0.074398    0.539683  2.202098  0.040613    1.640006
# 14            0.245077  0.063457    0.500000  2.040179  0.032354    1.509847
# 4             0.245077  0.056893    0.490566  2.001685  0.028470    1.481887
#
#     zhangs_metric
# 9        0.973081
# 10       0.913551
# 0        0.886524
# 1        0.864580
# 5        0.880076
# 6        0.849877
# 11       0.837922
# 12       0.935072
# 13       0.713415
# 2        0.756070
# 3        0.720512
# 8        0.723103
# 7        0.633174
# 14       0.583960
# 4        0.566070
